# %%
# lib import 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# loading database and creating previsors 
credit = pd.read_csv('Credit.csv')
credit.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
predictors = credit.iloc[:,0:20].values
vclass = credit.iloc[:,20].values

# %%
# categorical to numeric transformtaion
labelencoder = LabelEncoder()
predictors[:,0] = labelencoder.fit_transform(predictors[:,0])
predictors[:,2] = labelencoder.fit_transform(predictors[:,2])
predictors[:, 3] = labelencoder.fit_transform(predictors[:, 3])
predictors[:, 5] = labelencoder.fit_transform(predictors[:, 5])
predictors[:, 6] = labelencoder.fit_transform(predictors[:, 6])
predictors[:, 8] = labelencoder.fit_transform(predictors[:, 8])
predictors[:, 9] = labelencoder.fit_transform(predictors[:, 9])
predictors[:, 11] = labelencoder.fit_transform(predictors[:, 11])
predictors[:, 13] = labelencoder.fit_transform(predictors[:, 13])
predictors[:, 14] = labelencoder.fit_transform(predictors[:, 14])
predictors[:, 16] = labelencoder.fit_transform(predictors[:, 16])
predictors[:, 18] = labelencoder.fit_transform(predictors[:, 18])
predictors[:, 19] = labelencoder.fit_transform(predictors[:, 19])

# %%
# 70/30 split
X_training, X_test, y_training, y_test = train_test_split(predictors,
                                                                  vclass,
                                                                  test_size = 0.3,
                                                                  random_state = 0)

# %%
# creaintg and traning model, predicitons and hitrate 
forest = RandomForestClassifier(n_estimators = 100)
forest.fit(X_training, y_training)
# Out:
# RandomForestClassifier()

# %%
# most important attributes view
forest.estimators_
#forest.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=583197134),
#  DecisionTreeClassifier(max_features='auto', random_state=1000645773),
#  DecisionTreeClassifier(max_features='auto', random_state=9458793),
#  DecisionTreeClassifier(max_features='auto', random_state=990618650),
#  DecisionTreeClassifier(max_features='auto', random_state=284201634),
#  DecisionTreeClassifier(max_features='auto', random_state=841640358),
#  DecisionTreeClassifier(max_features='auto', random_state=666961876),
#  DecisionTreeClassifier(max_features='auto', random_state=1175044769),
#  DecisionTreeClassifier(max_features='auto', random_state=685808264),
#  DecisionTreeClassifier(max_features='auto', random_state=469218820),
#  DecisionTreeClassifier(max_features='auto', random_state=1935108314),
#  DecisionTreeClassifier(max_features='auto', random_state=686449223),
#  DecisionTreeClassifier(max_features='auto', random_state=1104573378),
#  DecisionTreeClassifier(max_features='auto', random_state=952720097),
#  DecisionTreeClassifier(max_features='auto', random_state=862956742),
#  DecisionTreeClassifier(max_features='auto', random_state=566547700),
#  DecisionTreeClassifier(max_features='auto', random_state=2004129575),
#  DecisionTreeClassifier(max_features='auto', random_state=939949792),
#  DecisionTreeClassifier(max_features='auto', random_state=66939080),
#  DecisionTreeClassifier(max_features='auto', random_state=166670059),
#  DecisionTreeClassifier(max_features='auto', random_state=586439930),
#  DecisionTreeClassifier(max_features='auto', random_state=1714749458),
#  DecisionTreeClassifier(max_features='auto', random_state=572403358),
#  DecisionTreeClassifier(max_features='auto', random_state=2030659473),
#  DecisionTreeClassifier(max_features='auto', random_state=1596164736),
#  DecisionTreeClassifier(max_features='auto', random_state=1084255844),
#  DecisionTreeClassifier(max_features='auto', random_state=787895492),
#  DecisionTreeClassifier(max_features='auto', random_state=1067398979),
#  DecisionTreeClassifier(max_features='auto', random_state=2125396329),
#  DecisionTreeClassifier(max_features='auto', random_state=66565671),
#  DecisionTreeClassifier(max_features='auto', random_state=1966321346),
#  DecisionTreeClassifier(max_features='auto', random_state=668679232),
#  DecisionTreeClassifier(max_features='auto', random_state=1011914166),
#  DecisionTreeClassifier(max_features='auto', random_state=838098588),
#  DecisionTreeClassifier(max_features='auto', random_state=452654452),
#  DecisionTreeClassifier(max_features='auto', random_state=717906298),
#  DecisionTreeClassifier(max_features='auto', random_state=615555031),
#  DecisionTreeClassifier(max_features='auto', random_state=1341031480),
#  DecisionTreeClassifier(max_features='auto', random_state=98017213),
#  DecisionTreeClassifier(max_features='auto', random_state=1532228813),
#  DecisionTreeClassifier(max_features='auto', random_state=408043526),
#  DecisionTreeClassifier(max_features='auto', random_state=1634654912),
#  DecisionTreeClassifier(max_features='auto', random_state=184337521),
#  DecisionTreeClassifier(max_features='auto', random_state=1791657749),
#  DecisionTreeClassifier(max_features='auto', random_state=801748388),
#  DecisionTreeClassifier(max_features='auto', random_state=281207378),
#  DecisionTreeClassifier(max_features='auto', random_state=2041596181),
#  DecisionTreeClassifier(max_features='auto', random_state=1166685013),
#  DecisionTreeClassifier(max_features='auto', random_state=1760692037),
#  DecisionTreeClassifier(max_features='auto', random_state=1747411345),
#  DecisionTreeClassifier(max_features='auto', random_state=1835754839),
#  DecisionTreeClassifier(max_features='auto', random_state=2018797807),
#  DecisionTreeClassifier(max_features='auto', random_state=672491868),
#  DecisionTreeClassifier(max_features='auto', random_state=1550354988),
#  DecisionTreeClassifier(max_features='auto', random_state=1604187665),
#  DecisionTreeClassifier(max_features='auto', random_state=2129878207),
#  DecisionTreeClassifier(max_features='auto', random_state=283411662),
#  DecisionTreeClassifier(max_features='auto', random_state=1682460126),
#  DecisionTreeClassifier(max_features='auto', random_state=76263485),
#  DecisionTreeClassifier(max_features='auto', random_state=1977753412),
#  DecisionTreeClassifier(max_features='auto', random_state=771834628),
#  DecisionTreeClassifier(max_features='auto', random_state=1132990805),
#  DecisionTreeClassifier(max_features='auto', random_state=794145291),
#  DecisionTreeClassifier(max_features='auto', random_state=1219754096),
#  DecisionTreeClassifier(max_features='auto', random_state=2119929424),
#  DecisionTreeClassifier(max_features='auto', random_state=904079860),
#  DecisionTreeClassifier(max_features='auto', random_state=706897826),
#  DecisionTreeClassifier(max_features='auto', random_state=1570248956),
#  DecisionTreeClassifier(max_features='auto', random_state=532438429),
#  DecisionTreeClassifier(max_features='auto', random_state=435150414),
#  DecisionTreeClassifier(max_features='auto', random_state=1598879834),
#  DecisionTreeClassifier(max_features='auto', random_state=358537276),
#  DecisionTreeClassifier(max_features='auto', random_state=2022010647),
#  DecisionTreeClassifier(max_features='auto', random_state=1012879495),
#  DecisionTreeClassifier(max_features='auto', random_state=1103390689),
#  DecisionTreeClassifier(max_features='auto', random_state=1377118908),
#  DecisionTreeClassifier(max_features='auto', random_state=1321027600),
#  DecisionTreeClassifier(max_features='auto', random_state=318421642),
#  DecisionTreeClassifier(max_features='auto', random_state=1478907698),
#  DecisionTreeClassifier(max_features='auto', random_state=1235565563),
#  DecisionTreeClassifier(max_features='auto', random_state=2010529167),
#  DecisionTreeClassifier(max_features='auto', random_state=5051356),
#  DecisionTreeClassifier(max_features='auto', random_state=1451156187),
#  DecisionTreeClassifier(max_features='auto', random_state=1296716306),
#  DecisionTreeClassifier(max_features='auto', random_state=598749097),
#  DecisionTreeClassifier(max_features='auto', random_state=1927480671),
#  DecisionTreeClassifier(max_features='auto', random_state=316382582),
#  DecisionTreeClassifier(max_features='auto', random_state=1117586346),
#  DecisionTreeClassifier(max_features='auto', random_state=1988892722),
#  DecisionTreeClassifier(max_features='auto', random_state=98920890),
#  DecisionTreeClassifier(max_features='auto', random_state=584706378),
#  DecisionTreeClassifier(max_features='auto', random_state=1178512635),
#  DecisionTreeClassifier(max_features='auto', random_state=1895472186),
#  DecisionTreeClassifier(max_features='auto', random_state=1153840989),
#  DecisionTreeClassifier(max_features='auto', random_state=1209807829),
#  DecisionTreeClassifier(max_features='auto', random_state=138982573),
#  DecisionTreeClassifier(max_features='auto', random_state=1838963305),
#  DecisionTreeClassifier(max_features='auto', random_state=926467876),
#  DecisionTreeClassifier(max_features='auto', random_state=568360962),
#  DecisionTreeClassifier(max_features='auto', random_state=1664500686)]

# %%
prevision = forest.predict(X_test)
confusion = confusion_matrix(y_test, prevision)
hitrate = accuracy_score(y_test, prevision)
hitrate
# Out:
# 0.8
